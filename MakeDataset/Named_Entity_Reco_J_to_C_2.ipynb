# %%
import json
import os 
import pandas as pd
file_path='./data./국립국어원 개체명 분석 말뭉치 2021(버전 1.0)./19_150tags_NamedEntity./'
file_list=os.listdir(file_path)

# %%
NER_df=pd.DataFrame(columns=['id','sentence','ori_form','label'])
index=0
print(file_path)
for i in file_list:
    print(i)
    with open(file_path+i,'r',encoding='UTF8') as file:
        data=json.load(file)
        print("도큐먼트 총 길이: ",len(data['document']))
        for i1 in range(len(data['document'])):
            if i1%100==0:
                print(i1)
            Ne_data=data['document'][i1]['sentence']
            for i2 in range(len(Ne_data)):
                info_data=Ne_data[i2]
                for i3 in (info_data['NE']):
                    value_l=[info_data['id'],info_data['form'],i3['form'],i3['label']]
                    NER_df.loc[index]=value_l
                    index+=1
# Out:
# ./data./국립국어원 개체명 분석 말뭉치 2021(버전 1.0)./19_150tags_NamedEntity./
# NXNE2102008030.json
# 도큐먼트 총 길이:  7265
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# SXNE2102007240.json
# 도큐먼트 총 길이:  423
# 0
# 100
# 200
# 300
# 400

# %%
print(len(NER_df))
# Out:
# 600377

# %%
NER_df.to_csv("NER_df.csv",index=False,encoding="utf-8-sig")

# %%
a=NER_df[:50000]
a.to_csv('test.csv',index=False,encoding="utf-8-sig")

# %%
import json
import os 
import pandas as pd
file_path='./data./국립국어원 개체명 분석 말뭉치 2021(버전 1.0)./21_150tags_NamedEntity./NXNE2102203310./'
file_list=os.listdir(file_path)

# %%
file_list
# Out:
# ['NXNE2102203310.json']

# %%
NER2_df=pd.DataFrame(columns=['id','sentence','ori_form','label'])
index=0
print(file_path)
for i in file_list:
    print(i)
    with open(file_path+i,'r',encoding='UTF8') as file:
        data=json.load(file)
        print("도큐먼트 총 길이: ",len(data['document']))
        for i1 in range(len(data['document'])):
            if i1%100==0:
                print(i1)
            Ne_data=data['document'][i1]['sentence']
            for i2 in range(len(Ne_data)):
                info_data=Ne_data[i2]
                for i3 in (info_data['NE']):
                    value_l=[info_data['id'],info_data['form'],i3['form'],i3['label']]
                    NER2_df.loc[index]=value_l
                    index+=1
# Out:
# ./data./국립국어원 개체명 분석 말뭉치 2021(버전 1.0)./21_150tags_NamedEntity./NXNE2102203310./
# NXNE2102203310.json
# 도큐먼트 총 길이:  1678
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600

# %%
NER2_df.to_csv("NER2_df.csv",index=False,encoding="utf-8-sig")

# %%
import json
import os 
import pandas as pd
file_path='./data./국립국어원 개체명 분석 말뭉치 2021(버전 1.0)./21_150tags_NamedEntity./SXNE2102203310./'
file_list=os.listdir(file_path)
NER3_df=pd.DataFrame(columns=['id','sentence','ori_form','label'])
index=0
print(file_path)
for i in file_list:
    print(i)
    with open(file_path+i,'r',encoding='UTF8') as file:
        data=json.load(file)
        print("도큐먼트 총 길이: ",len(data['document']))
        for i1 in range(len(data['document'])):
            if i1%100==0:
                print(i1)
json
# 도큐먼트 총 길이:  1
# 0
# SBNE2100014742.json
# 도큐먼트 총 길이:  1
# 0
# SBNE2100014743.json
# 도큐먼트 총 길이:  1
# 0

# %%
NER3_df.to_csv("NER3_df.csv",index=False,encoding="utf-8-sig")

# %%
import pandas as pd

# %%
df1=pd.read_csv("NER_df.csv")

# %%
df1
# Out:
#                             id  \
# 0       NWRW1800000029.315.1.1
# 1       NWRW1800000029.315.1.1
# 2       NWRW1800000029.315.2.1
# 3       NWRW1800000029.315.2.1
# 4       NWRW1800000029.315.2.1
# ...                        ...
# 600372     SBRW1800000036.1957
# 600373     SBRW1800000036.1959
# 600374     SBRW1800000036.1963
# 600375     SBRW1800000036.1970
# 600376     SBRW1800000036.1974
#
#                                                  sentence ori_form  \
# 0                                 [횡설수설/권순활]北 ‘외화벌이’ 뜯어먹기      권순활
# 1                                 [횡설수설/권순활]北 ‘외화벌이’ 뜯어먹기        北
# 2       필리핀 국민의 약 10%인 800만 명은 세계 곳곳에서 건설노동자 가정부 유모 등으...      필리핀
# 3       필리핀 국민의 약 10%인 800만 명은 세계 곳곳에서 건설노동자 가정부 유모 등으...    약 10%
# 4       필리핀 국민의 약 10%인 800만 명은 세계 곳곳에서 건설노동자 가정부 유모 등으...   800만 명
# ...                                                   ...      ...
# 600372                                          이 외교관을 새로      외교관
# 600373                         또 우리 외교관들에게 주어진 책무에 대해서 함께      외교관
# 600374                                           우리 외교관들은      외교관
# 600375                                    아~ 국립외교원에 거는 기대    국립외교원
# 600376                                       다음 주에 뵙겠습니다.     다음 주
#
#                 label
# 0             PS_NAME
# 1         LCP_COUNTRY
# 2         LCP_COUNTRY
# 3       QT_PERCENTAGE
# 4        QT_MAN_COUNT
# ...               ...
# 600372  CV_OCCUPATION
# 600373  CV_OCCUPATION
# 600374  CV_OCCUPATION
# 600375   OGG_POLITICS
# 600376        DT_WEEK
#
# [600377 rows x 4 columns]

# %%
df2=pd.read_csv("NER2_df.csv")
df2
# Out:
#                                id  \
# 0           NIRW2000000001.91.1.1
# 1           NIRW2000000001.91.2.1
# 2           NIRW2000000001.91.2.1
# 3           NIRW2000000001.91.2.1
# 4           NIRW2000000001.91.2.1
# ...                           ...
# 191228  NWRW2000000003.48108.16.2
# 191229  NWRW2000000003.48108.16.2
# 191230  NWRW2000000003.48108.16.2
# 191231  NWRW2000000003.48108.16.2
# 191232  NWRW2000000003.48108.16.2
#
#                                                  sentence ori_form  \
# 0                          종합적인 해양수산정보 관리 기반 마련...121억 투입     121억
# 1       정부는 인공지능 및 빅데이터를 활용해 새로운 부가가치를 창출하고 종합적인 해양수산정...       정부
# 2       정부는 인공지능 및 빅데이터를 활용해 새로운 부가가치를 창출하고 종합적인 해양수산정...     인공지능
# 3       정부는 인공지능 및 빅데이터를 활용해 새로운 부가가치를 창출하고 종합적인 해양수산정...  2021년까지
# 4       정부는 인공지능 및 빅데이터를 활용해 새로운 부가가치를 창출하고 종합적인 해양수산정...   121억 원
# ...                                                   ...      ...
# 191228  임 대표 딸인 임수진 산울림 극장장은 “50년 동안 산울림을 사랑해온 관객들이 이번...      임수진
# 191229  임 대표 딸인 임수진 산울림 극장장은 “50년 동안 산울림을 사랑해온 관객들이 이번...      산울림
# 191230  임 대표 딸인 임수진 산울림 극장장은 “50년 동안 산울림을 사랑해온 관객들이 이번...      극장장
# 191231  임 대표 딸인 임수진 산울림 극장장은 “50년 동안 산울림을 사랑해온 관객들이 이번...   50년 동안
# 191232  임 대표 딸인 임수진 산울림 극장장은 “50년 동안 산울림을 사랑해온 관객들이 이번...      산울림
#
#                label
# 0           QT_PRICE
# 1       OGG_POLITICS
# 2         TR_SCIENCE
# 3          DT_OTHERS
# 4           QT_PRICE
# ...              ...
# 191228       PS_NAME
# 191229       OGG_ART
# 191230   CV_POSITION
# 191231   DT_DURATION
# 191232       OGG_ART
#
# [191233 rows x 4 columns]

# %%
df3=pd.read_csv("NER3_df.csv")
df3
# Out:
#                              id  \
# 0          SARW1900000895.1.1.5
# 1          SARW1900000895.1.1.5
# 2          SARW1900000895.1.1.5
# 3          SARW1900000895.1.1.6
# 4          SARW1900000895.1.1.8
# ...                         ...
# 189437  SBRW1900014743.1.1.1086
# 189438  SBRW1900014743.1.1.1087
# 189439  SBRW1900014743.1.1.1087
# 189440  SBRW1900014743.1.1.1087
# 189441  SBRW1900014743.1.1.1087
#
#                                                  sentence    ori_form  \
# 0       아~ 제목을 그냥 탄소 아~ 그리고 인간 원리 다중 우주 아~ 이런 제목을 잡았는데...          탄소
# 1       아~ 제목을 그냥 탄소 아~ 그리고 인간 원리 다중 우주 아~ 이런 제목을 잡았는데...         물리학
# 2       아~ 제목을 그냥 탄소 아~ 그리고 인간 원리 다중 우주 아~ 이런 제목을 잡았는데...         천문학
# 3                                 그니까 현대 우주론이 사실은 어디까지 왔나         우주론
# 4                                  그리고 현대 우주론의 딜레마가 무엇인가?         우주론
# ...                                                   ...         ...
# 189437   말린 구기자의 경우는 이십 그램 정도 이하 그러니까 두 스푼 정도라고 보시면 되겠고요.     두 스푼 정도
# 189438  구기자를 갈아서 추출해서 만든 분말의 경우에는 삼에서 오 그람 정도 약 일 티스푼 ...         구기자
# 189439  구기자를 갈아서 추출해서 만든 분말의 경우에는 삼에서 오 그람 정도 약 일 티스푼 ...           삼
# 189440  구기자를 갈아서 추출해서 만든 분말의 경우에는 삼에서 오 그람 정도 약 일 티스푼 ...     오 그람 정도
# 189441  구기자를 갈아서 추출해서 만든 분말의 경우에는 삼에서 오 그람 정도 약 일 티스푼 ...  약 일 티스푼 정도
#
#              label
# 0       MT_ELEMENT
# 1       FD_SCIENCE
# 2       FD_SCIENCE
# 3       TR_SCIENCE
# 4       TR_SCIENCE
# ...            ...
# 189437    QT_COUNT
# 189438    PT_FRUIT
# 189439   QT_WEIGHT
# 189440   QT_WEIGHT
# 189441    QT_COUNT
#
# [189442 rows x 4 columns]
