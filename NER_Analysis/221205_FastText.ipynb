# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pickle
with open('/content/drive/MyDrive/Colab Notebooks/AURA2/data/pickle/Final_result_list(basic).pkl','rb') as f:
  Final_result_list_basic = pickle.load(f)

with open('/content/drive/MyDrive/Colab Notebooks/AURA2/data/pickle/Final_result_list(Per).pkl','rb') as f:
  Final_result_list_per = pickle.load(f)

with open('/content/drive/MyDrive/Colab Notebooks/AURA2/data/pickle/Final_result_list(each_2).pkl','rb') as f:
  Final_result_list_each = pickle.load(f)

# %%
len(Final_result_list_basic)
# Out:
# 10000

# %%
len(Final_result_list_per)
# Out:
# 10000

# %%
len(Final_result_list_each)
# Out:
# 10000

# %%
Final_result_list_basic[1][0]
# Out:
# [['그러네', '가장', '최근', '에', '뭐삼?'],
#  ['가장',
#   '최근',
#   '에',
#   '산',
#   '거',
#   '에스트라',
#   '샘플',
#   '삼',
#   '도착',
#   '은',
#   '했는데',
#   '언제쯤',
#   '개봉',
#   '할지',
#   '미지',
#   '수'],
#  ['나도',
#   '에스트라',
#   '저번',
#   '주에',
#   '샀는데',
#   '귀찮아',
#   '서',
#   '안',
#   '뜯다가',
#   '이거',
#   '시작',
#   '하기',
#   '전에',
#   '택배',
#   '박스',
#   '싹',
#   '정리',
#   '아토피',
#   '에',
#   '그래도',
#   '그나마',
#   '효과',
#   '있다고',
#   '생각',
#   '되는',
#   '게',
#   '에스트라',
#   '인',
#   '듯',
#   '딴',
#   '건',
#   '그냥',
#   '피부',
#   '에',
#   '바르면',
#   '무난하고',
#   '아도',
#   '아토피',
#   '에는',
#   '오히려',
#   '자극적',
#   '이거나',
#   '하나도',
#   '보습',
#   '감',
#   '없고'],
#  ['에스트라',
#   '가',
#   '피부',
#   '과에서',
#   '파는',
#   '거랑',
#   '그냥',
#   '쇼핑몰',
#   '에서',
#   '파는',
#   '거랑',
#   '성분',
#   '다르다는',
#   '말이',
#   '있던데',
#   '그냥',
#   '사도',
#   '괜찮음?'],
#  ['일단',
#   '사봄',
#   '지금',
#   '쓰는',
#   '거',
#   '반',
#   '정도',
#   '남아',
#   '가지고',
#   '가격',
#   '은',
#   '비슷',
#   '하던데',
#   '안되면',
#   '처방',
#   '해주는',
#   '피부',
#   '과',
#   '찾봐야',
#   '할',
#   '듯',
#   '요즘',
#   '기초',
#   '제품',
#   '은',
#   '뭐',
#   '쓰세요?'],
#  ['요즘',
#   '은',
#   '스킨푸드',
#   '에서',
#   '산거',
#   '네고',
#   '왕',
#   '때',
#   '샀던',
#   '수분',
#   '크림',
#   '이제',
#   '뜯어',
#   '서',
#   '쓰고',
#   '있어요'],
#  ['시기가',
#   '비슷',
#   '한가',
#   '보다',
#   '저도',
#   '요',
#   '노란',
#   '거',
#   '이제',
#   '쓰는',
#   '중',
#   '나쁘지',
#   '않음',
#   '그리고',
#   '그때',
#   '산',
#   '원청',
#   '비싼',
#   '거',
#   '캐비아',
#   '무엇',
#   '도',
#   '같이',
#   '쓰는',
#   '중인데',
#   '잘',
#   '모르곗음',
#   '일단',
#   '용기',
#   '가',
#   '유리',
#   '라서',
#   '너무',
#   '무겁'],
#  ['아', '그', '착한', '수분', '크림', '어쩌고', '너도', '쓰고', '있니'],
#  ['야스', '그거', '쓰는', '중'],
#  ['화장품', '사놓은', '거', '다', '쓰고', '새로', '사야지'],
#  ['맞아', '나', '지금', '앰풀', '사뉸게', '너무', '많다', '겁나', '부지런', '히', '써야', '해'],
#  ['면세', '로', '뭐', '살', '거야?'],
#  ['부기',
#   '나갔다',
#   '올',
#   '때?',
#   '생각',
#   '안',
#   '해봤는데',
#   '짐',
#   '안될',
#   '만한',
#   '거',
#   '있으면',
#   '좀',
#   '구경',
#   '해봐야겠다',
#   '넌',
#   '??'],
#  ['아마', '틴트', '살듯', '차차', '거의', '다', '써가지고']]

# %%
Final_result_list_each[0][0]

# %%
Final_result_list_per[0][0]

# %%
#with open('/content/drive/MyDrive/Colab Notebooks/AURA2/data/Final_result_list.pkl','rb') as f:
#  Final_result_list= pickle.load(f)

# %%
#import pickle
#with open('/content/drive/MyDrive/Colab Notebooks/AURA2/data/X_train.pkl','rb') as f:
#  X_train = pickle.load(f)

# %% [markdown]
# ### FastText 불러오기

# %%
# !pip install --upgrade gensim==3.8.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting gensim==3.8.0
#   Downloading gensim-3.8.0.tar.gz (23.4 MB)
#      |████████████████████████████████| 23.4 MB 14.8 MB/s
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.8/dist-packages (from gensim==3.8.0) (1.21.6)
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.8/dist-packages (from gensim==3.8.0) (1.7.3)
# Requirement already satisfied: six>=1.5.0 in /usr/local/lib/python3.8/dist-packages (from gensim==3.8.0) (1.15.0)
# Requirement already satisfied: smart_open>=1.7.0 in /usr/local/lib/python3.8/dist-packages (from gensim==3.8.0) (5.2.1)
# Building wheels for collected packages: gensim
#   Building wheel for gensim (setup.py) ... done
#   Created wheel for gensim: filename=gensim-3.8.0-cp38-cp38-linux_x86_64.whl size=25868854 sha256=53ff763bd3753867c59eae50011dc12e40977dee245b4e7aa121db23f6909147
#   Stored in directory: /root/.cache/pip/wheels/09/d1/44/6d6dcb820e282b40ccfce6d2bb0101c24d7fffd863b2276783
# Successfully built gensim
# Installing collected packages: gensim
#   Attempting uninstall: gensim
#     Found existing installation: gensim 3.6.0
#     Uninstalling gensim-3.6.0:
#       Successfully uninstalled gensim-3.6.0
# Successfully installed gensim-3.8.0

# %%
from gensim import models

ko_model = models.fasttext.load_facebook_model('/content/drive/MyDrive/Colab Notebooks/FastText_pretrained/cc.ko.300.bin')
# Out:
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'\xed\xa1\x9c'; replacing invalid characters, using '\\xed\\xa1\\x9c'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'\xed\xb0\x80'; replacing invalid characters, using '\\xed\\xb0\\x80'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'\xed\xa7\x80'; replacing invalid characters, using '\\xed\\xa7\\x80'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'\xed\xb8\xb0'; replacing invalid characters, using '\\xed\\xb8\\xb0'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'\xed\xa0\x9c'; replacing invalid characters, using '\\xed\\xa0\\x9c'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'\xed\xa6\xac'; replacing invalid characters, using '\\xed\\xa6\\xac'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'\xed\xb3\xb5'; replacing invalid characters, using '\\xed\\xb3\\xb5'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'\xed\xb3\xb4'; replacing invalid characters, using '\\xed\\xb3\\xb4'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'\xed\xa5\xbc'; replacing invalid characters, using '\\xed\\xa5\\xbc'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'\xed\xb3\xa0'; replacing invalid characters, using '\\xed\\xb3\\xa0'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'\xed\xa0\x84'; replacing invalid characters, using '\\xed\\xa0\\x84'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'\xed\xa0\x95'; replacing invalid characters, using '\\xed\\xa0\\x95'

# %%
from numpy import dot
from numpy.linalg import norm
import numpy as np

def cos_sim(A, B):
  return dot(A, B)/(norm(A)*norm(B))

# %% [markdown]
# #### 태그를 대표어로 replace

# %%
import pandas as pd
tag_represent = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/AURA2/data/태깅DICT.CSV', encoding='cp949')
tag_represent.head()
# Out:
#              PS_NAME    인물이름
# 0       PS_CHARACTER   캐릭터이름
# 1             PS_PET  반려동물이름
# 2         FD_SCIENCE      과학
# 3  FD_SOCIAL_SCIENCE    사회과학
# 4        FD_MEDICINE      의학

# %%
tag_to_represent = {'PS_NAME' : '인물이름'}
for i in range(1, len(tag_represent)) :
  if str(tag_represent.loc[i, 'PS_NAME']) == "TM_SELL_TISSUE_ORGAN" :
    tag_to_represent["TM_CELL_TISSUE_ORGAN"] = str(tag_represent.loc[i, '인물이름'])
    continue
  tag_to_represent[str(tag_represent.loc[i, 'PS_NAME'])] = str(tag_represent.loc[i, '인물이름'])

# %%
len(tag_represent) == len(tag_to_represent)
# Out:
# True

# %% [markdown]
# #### 문장의 임베딩 평균을 이용한 유사도

# %%
# ner사용하지 않고, 단순히 문장 간 유사도 비교
def fasttext_sim(convrs, model, tag_to_represent) : # model : FastText model
  cos_sim_lst = []
  sentences = []
  
  ners = []
  for i in range(0, len(convrs[0]), 2) :
    if len(convrs[0]) % 2 == 0 : # 개수가 짝수
      sent1 = convrs[0][i]
      ner1 = convrs[1][i]
      sent2 = convrs[0][i+1]
      ner2 = convrs[1][i+1]
      sentences.append(sent1)
      sentences.append(sent2)
      ners.append(ner1)
      ners.append(ner2)
    else :
      if i == len(convrs[0])-1 :
        sentences.append(convrs[0][i])
        ners.append(convrs[1][i])
        break
      else :
        sent1 = convrs[0][i]
        ner1 = convrs[1][i]
        sent2 = convrs[0][i+1]
        ner2 = convrs[1][i+1]
        sentences.append(sent1)
        sentences.append(sent2)
        ners.append(ner1)
        ners.append(ner2)

  #print(sentences)
  og_sentences = sentences[:]
  tmp_sent_len = [len(s) for s in sentences]
  tmp_ner_len = [len(t) for t in ners]
  #print(tmp_sent_len, tmp_ner_len)
  
  
  # ner 태그를 sent에 replace하기
  for i in range(len(sentences)) :
    #print(sentences[i])
    #print(ners[i])
    for j in range(len(sentences[i])) :
      if len(ners[i]) < len(sentences[i]) and j == len(ners[i]) -1 :
        break
      if ners[i][j] == 'PAD' :
        break
      elif ners[i][j] == 'O' :
        continue
      else :
        sentences[i][j] = ners[i][j]
  
  # B-AFA_DOCUMENT I-AFA_DOCUMENT -> 합친 후 AFA_DOCUMENT로 통일
  tmp_sentences = []
  #print("og", sentences)
  for i in range(len(sentences)) :
    tmp_sentence = []
    tmp_ner = ''
    for j in range(len(sentences[i])) :
      if len(sentences[i][j]) == 0 :
        continue
      #if sentences[i][j].isalpha() :
        #print("HO")
      #print(sentences[i][j])
      if sentences[i][j][:2] == 'B-' :
        if j == len(sentences[i]) - 1 :# 마지막
          tmp_sentence.append(sentences[i][j][2:])
          tmp_ner = ''
          continue
        elif j != len(sentences[i]) - 1 and sentences[i][j+1][:2] != 'I-' :
          tmp_sentence.append(sentences[i][j][2:])
          tmp_ner = ''
          continue
        else :
          tmp_ner = sentences[i][j][2:]
          continue
      if j == len(sentences[i]) - 1 :
        if sentences[i][j][:2] == 'I-' :
          tmp_sentence.append(sentences[i][j][2:])
      elif sentences[i][j][:2] == 'I-' and sentences[i][j][2:] == tmp_ner and sentences[i][j+1][2:] == tmp_ner :
        #print("hello")
        continue
      elif sentences[i][j][:2] == 'I-' and sentences[i][j][2:] == tmp_ner and sentences[i][j+1][2:] != tmp_ner :
        #print("hi")
        tmp_sentence.append(tmp_ner)
      else :
        tmp_sentence.append(sentences[i][j])
    tmp_sentences.append(tmp_sentence)
  sentences_ = tmp_sentences[:]
  #print("after", sentences_) # 태그가 sentence에 안들어가는 문제 발생
  #new_sentences = [' '.join(s) for s in sentences_]
  #print(new_sentences)
  #print(sentences_)
  
  # tag to represent
  for i in range(len(sentences_)) :
    for j in range(len(sentences_[i])) :
      if sentences_[i][j] in tag_to_represent :
        sentences_[i][j] = tag_to_represent[sentences_[i][j]]
  #print(sentences_)

  # 유사도 계산
  sentences_embedding = []
  for i in range(len(sentences_)) :
    tmp = 0
    for j in range(len(sentences_[i])) :
      #print(model[sentences_[i][j]])
      #if np.isnan(model[sentences[i][j]]) :
      #  continue
      #else : 
      tmp += model[sentences_[i][j]]
    if len(sentences_[i]) == 0 :
      return [0], 0
    sentences_embedding.append(tmp / len(sentences_[i])) # 단어 임베딩들을 모두 합한 후 평균낸다.
  #print(sentences_embedding)
  
  # sentences간 cos_sim 구하기
  for i in range(len(sentences_embedding) - 1) :
    #print(sentences_embedding[i+1])
    cos_sim_lst.append(cos_sim(sentences_embedding[i], sentences_embedding[i+1]))
  if len(cos_sim_lst) == 0 :
    return [0], 0
  return cos_sim_lst, sum(cos_sim_lst)/len(cos_sim_lst)

# %%
# test
fasttext_sim(Final_result_list_basic[1], ko_model, tag_to_represent)

# %%
convrs_sim_avg = []
convrs_sim_basic = []
convrs_sim_per = []
convrs_sim_each = []

for i in range(len(Final_result_list_basic)) :
  ft_sim = fasttext_sim(Final_result_list_basic[i], ko_model, tag_to_represent)[1]
  convrs_sim_basic.append(ft_sim)

for i in range(len(Final_result_list_each)) :
  ft_sim = fasttext_sim(Final_result_list_each[i], ko_model, tag_to_represent)[1]
  convrs_sim_each.append(ft_sim)

for i in range(len(Final_result_list_per)) :
  ft_sim = fasttext_sim(Final_result_list_per[i], ko_model, tag_to_represent)[1]
  convrs_sim_per.append(ft_sim)

# %%
len(convrs_sim_basic), len(convrs_sim_per), len(convrs_sim_each)
# Out:
# (10000, 10000, 10000)

# %%
import pickle
with open('convrs_sim_basic.pkl','wb') as f:
  pickle.dump(convrs_sim_basic,f)

with open('convrs_sim_each.pkl','wb') as f:
  pickle.dump(convrs_sim_each,f)

with open('convrs_sim_per.pkl','wb') as f:
  pickle.dump(convrs_sim_per,f)

# %%
convrs_sim_avg = [(convrs_sim_basic[i] + convrs_sim_each[i] + convrs_sim_per[i]) / 3 for i in range(len(convrs_sim_basic))]
len(convrs_sim_avg)
# Out:
# 10000

# %%
convrs_sim_tuple = []
for i in range(len(convrs_sim_avg)) :
  convrs_sim_tuple.append((convrs_sim_avg[i], i))
convrs_sim_tuple

# %%
convrs_sim_tuple_asc = sorted(convrs_sim_tuple, key = lambda x : x[0])
convrs_sim_tuple_asc[:-5:-1]
# Out:
# [(0.8987034024614275, 4867),
#  (0.8693898968207531, 7717),
#  (0.8682966050776568, 7133),
#  (0.8646937932214166, 7278)]

# %%
def extract_max_min_n(X, sim, n = 5) :
  min_idx = [s[1] for s in convrs_sim_tuple_asc[:n]]
  max_idx = [s[1] for s in convrs_sim_tuple_asc[-1:-1-n:-1]]

  max_lst = [X[i][0] for i in max_idx]
  min_lst = [X[i][0] for i in min_idx]

  return max_lst, min_lst

# %%
max_convrs, min_convrs = extract_max_min_n(Final_result_list_basic, convrs_sim_tuple_asc, 3) # Final_result_list_basic 바껴있어서 피클로 다시한번 불러와야함

# %%
min_convrs
# Out:
# [[[],
#   [],
#   ['숏', '스터', '지면', '어디', '갈까', '요?'],
#   ['일단'],
#   ['여행지', '추천', '좀요', '네에'],
#   ['일본', '1주', '동남아', '3주'],
#   ['일본', '싫어'],
#   ['유럽', '2달'],
#   ['방사능', '~', '으응'],
#   ['뉴질랜드', '4박', '5일', '미국', '1달', '캐나다', '2주', '이', '정도', '?'],
#   ['일본', '대신', '어디가?'],
#   ['일본', '음식', '맛있다', '그래서', '가보고', '싶은데'],
#   ['난', '달아', '양', '적어', 'ㅡㅡ'],
#   ['우리', '는', '돈', '많아', '플렉스', '~0~'],
#   ['그럼', '혼자가'],
#   ['일단', '국내', '고기', '맛', '집은', '다', '가고'],
#   ['응'],
#   ['스시', '맛', '집도', '다', '가고', '제주도', '도', '가야', '지'],
#   ['스시', '맛', '집은', '좀', '그래'],
#   ['그럼', '일본', '말고'],
#   ['제주도', '는', '질렸어'],
#   ['팔라우', '팔라완'],
#   ['1달', '살고', '와서'],
#   ['나는', '못', '가본', '곳이', '많아'],
#   ['나', '방콕', '가서', '안마', '받고', '싶어', '풍팟퐁커리먹을래'],
#   ['방콕',
#    '가서',
#    '코끼리',
#    '타야지',
#    '마사지도',
#    '받고',
#    '앙코르와트',
#    '도',
#    '가보고',
#    '싶고',
#    '잉카',
#    '마야문명',
#    '도',
#    '가보고',
#    '싶어'],
#   ['코끼리', '안', '좋아', '키우는', '환경', '이', '학대', '해서', '키운대', 'ㅜㅜ'],
#   ['방콕',
#    '가서',
#    '코끼리',
#    '타야지',
#    '마사지도',
#    '받고',
#    '앙코르와트',
#    '도',
#    '가보고',
#    '싶고',
#    '잉카',
#    '마야문명',
#    '도',
#    '가보고',
#    '싶어']],
#  [['무교'],
#   ['아'],
#   ['무교', '무교'],
#   ['아놔'],
#   ['그러면', '내가', '작가', '인데'],
#   ['하', '쓸'],
#   ['세상',
#    '사람들',
#    '이',
#    '내가',
#    '비엘',
#    '작가',
#    '인',
#    '거',
#    '알기',
#    '내가',
#    '사놓은',
#    '리디봄툰',
#    '서재',
#    '다',
#    '공개',
#    '해야',
#    '함',
#    '근데',
#    '돈은',
#    '잘',
#    '벎',
#    'vs',
#    '로맨스',
#    '소설',
#    '쓰면서',
#    '사람들',
#    '이',
#    '내',
#    '얼굴',
#    '모름',
#    '작품',
#    '은',
#    '유명',
#    '근데',
#    '불법',
#    '돈',
#    '퍼져',
#    '서',
#    '돈',
#    '못',
#    '범'],
#   ['님',
#    '작가',
#    '됐는데BL',
#    '웹툰',
#    '그려서',
#    '대박',
#    '났는데',
#    '광고',
#    '에',
#    '님',
#    '얼굴',
#    '과',
#    '흉한',
#    '장면',
#    '한',
#    '번에',
#    '클로즈업',
#    'VS',
#    'BL',
#    '웹툰',
#    '그렸는데',
#    '소소',
#    '하게',
#    '돈',
#    '들어옴',
#    '대신',
#    '홍보',
#    '안',
#    '해줌',
#    '아'],
#   ['가끔', '오는', '팬', '레터', '에', '후원', '존재'],
#   ['똑같은', '거', '봐', '하'],
#   ['신세계', '상품권', '이런', '거'],
#   [],
#   ['레전드', '나', '후자요'],
#   ['저', 'BL', '작가', '성동애', '강국', '내가', '만들어보자고'],
#   ['우리', '부모', '님', '그런', '거', '몰라'],
#   ['어?'],
#   ['울', '오빠', '비엘', '굿즈'],
#   ['아놔', '님', '세계', '가는', '부잔데?'],
#   ['그냥',
#    '귀여운',
#    '캐릭터',
#    '인',
#    '줄',
#    '알고',
#    '들고',
#    '다녔다고요',
#    '저거',
#    '하명',
#    '빌',
#    '게이츠',
#    '이길',
#    '수',
#    '있어요?',
#    '그럼',
#    '전자',
#    '우리',
#    '부모',
#    '님도',
#    '원하실',
#    '듯'],
#   ['하', '쓸', '불가능', '합니다'],
#   [],
#   ['재용', '이랑', '비비는', '정도'],
#   ['온~!'],
#   [],
#   ['엇', '샘', '속?', '그', '정도', '면', '뭐', '전자'],
#   ['오케이'],
#   ['그걸', '아셔야', '해요'],
#   ['아놔', '자낳괴'],
#   ['내가', '샘', '속처럼', '돈이', '많은데', '벨은', '본다?'],
#   ['네?'],
#   ['그러면', '벨이', '힙한', '문화', '가', '된다고요'],
#   ['성동애강국', '#가보자고'],
#   ['키오스크', '처럼', '못', '다루면', '뒤처지는', '그런', '나', '재용', '으로', '#', '만들어주라고'],
#   ['님', '저', '전자요', '무조건', '전자합니다', '왜냐', '하면'],
#   ['님이', '15', '초', '광고', '중에'],
#   ['성동애강국', '선두', '주자', '바로', '저', '아놔'],
#   ['한마디', '할', '때마다'],
#   ['네'],
#   ['신', '나와도요?'],
#   ['아'],
#   ['안녕', '(그것)', '하세요(그것)', '저는(그것)'],
#   ['근데', '저희', '집은', '알긴', '해요'],
#   [],
#   ['그런ㅐ인거'],
#   ['저희',
#    '부모',
#    '님도',
#    '얼추',
#    '아는',
#    '것',
#    '같긴',
#    '해요',
#    '모르는',
#    '척해',
#    '주는',
#    '게',
#    '아닐까',
#    '생각',
#    '중'],
#   ['근데', '약간', '그거', '죠', '면전에서', '읽냐', '아니냐', '차이', '저희', '집기독교거든요;']],
#  [['더쿠재밌떠'],
#   [],
#   ['하게', '최고야'],
#   ['더쿠하냐거', '물어볼', '수', '없읏다'],
#   [],
#   [],
#   ['그', '카톡', '방', '있었잖아요', '아직', '안', '나갔나요?'],
#   ['무슨', '카톡', '방이오?'],
#   ['그', '전남', '칫있던곳이요', '남자친구', '가', '생겨서', '잊어버린', '그', '방'],
#   ['앜', '맞다'],
#   [],
#   ['아직', '있어요', '참'],
#   ['아', '세상', '에', '오래', '가는', '곳이네요'],
#   ['그냥', '한', '명이', '맨날', '대화', '주제', '가져와서'],
#   ['아', '심지어', '얘기', '도', '이어나가?', '그냥', '잊혀버린', '방도', '아니고'],
#   ['어', '난', '말', '안', '한다', '이제'],
#   ['눈팅', '만하는곳이되었네', '하긴', '할', '말도', '없지', '모', '*_*'],
#   ['엉근데',
#    '한',
#    '10년',
#    '넘게',
#    '온라인',
#    '으로',
#    '떠든',
#    '방이었으니',
#    '떠들',
#    '만큼',
#    '떠든',
#    '거',
#    '아닐까']]]

# %%
max_convrs
# Out:
# [[['안녕', '하세요!', '학생', '이신가요?'],
#   ['안녕',
#    '하세요',
#    '학생',
#    '은',
#    '아니지만',
#    '학창시절',
#    '기억',
#    '은',
#    '있어요',
#    '지금',
#    '드는',
#    '생각',
#    '은',
#    '급식',
#    '이',
#    '진짜',
#    '좋은',
#    '거였구나',
#    '하는',
#    '생각',
#    '이에요',
#    '성인',
#    '되고',
#    '영양',
#    '챙겨',
#    '먹으려니',
#    '은근',
#    '번거',
#    '롭더라고요'],
#   ['저도',
#    '그렇게',
#    '생각',
#    '해요!',
#    '학교',
#    '다닐',
#    '때는',
#    '몰랐는데',
#    '영양요소',
#    '다',
#    '챙긴',
#    '급식',
#    '이',
#    '그립더라고요',
#    '매일',
#    '뭐',
#    '먹을지',
#    '고민',
#    '안',
#    '해도',
#    '되고',
#    '그렇지만',
#    '과제',
#    '나',
#    '시험',
#    '은',
#    '그립지',
#    '않네요'],
#   ['맞아요',
#    '과',
#    '제랑',
#    '시험',
#    '은',
#    '절레절레',
#    '아침',
#    '일찍',
#    '일어',
#    '나서',
#    '준비',
#    '하는',
#    '것도',
#    '은근',
#    '빡셌던',
#    '것',
#    '같아요',
#    '머리',
#    '긴',
#    '친구',
#    '들은',
#    '겨울',
#    '에',
#    '머리',
#    '감고',
#    '안',
#    '말리고',
#    '등교',
#    '하면',
#    '머리카락',
#    '이',
#    '얼어서',
#    '바삭바삭',
#    '해졌었는데',
#    '서로',
#    '너',
#    '머리카락',
#    '고드름',
#    '됐다면서',
#    '깔깔',
#    '웃고',
#    '했던',
#    '기억',
#    '이',
#    '나요',
#    '여름',
#    '때면',
#    '창밖',
#    '으로',
#    '매미',
#    '우는소리랑',
#    '체육시간',
#    '인',
#    '애들',
#    '이',
#    '떠드는',
#    '소리',
#    '가',
#    '들려오던',
#    '것도',
#    '떠오르고',
#    '점심시간',
#    '전에',
#    '배고파서',
#    '수업',
#    '언제',
#    '끝나나',
#    '시계',
#    '만',
#    '보던',
#    '것도',
#    '생각',
#    '나요',
#    '은',
#    '학창시절',
#    '기억',
#    '에',
#    '남는',
#    '추억',
#    '이',
#    '있나요?'],
#   ['아',
#    '맞아요',
#    '!',
#    '아침',
#    '에',
#    '머리',
#    '감고',
#    '바쁘다고',
#    '그냥',
#    '나오면',
#    '바삭바삭',
#    '제가',
#    '다니던',
#    '학교',
#    '는',
#    '좀',
#    '시골',
#    '이어서',
#    '학교',
#    '의',
#    '3면이',
#    '논이었는데요',
#    '여름',
#    '에',
#    '야',
#    '자',
#    '하다',
#    '보면',
#    '개구리울음소리',
#    '로',
#    '시끄러웠던',
#    '기억',
#    '이',
#    '나요',
#    '매점',
#    '도',
#    '없어서',
#    '담너머',
#    '슈퍼',
#    '쪽으로',
#    '애타게',
#    '부르면',
#    '슈퍼',
#    '주인',
#    '이',
#    '과자',
#    '나',
#    '빵',
#    '한',
#    '아름',
#    '안고',
#    '나오셔서',
#    '사',
#    '먹고ᄏᄏᄏ',
#    '시골',
#    '이어서',
#    '딱히',
#    '재밌는',
#    '게',
#    '있었나?',
#    '싶은데',
#    '그',
#    '나이',
#    '때는',
#    '공부',
#    '빼곤',
#    '다',
#    '재밌었던',
#    '것',
#    '같아요'],
#   ['으아',
#    '이야기',
#    '보니까',
#    '아련',
#    '해져요',
#    '맞아요',
#    '진짜',
#    '공부',
#    '빼고',
#    '다',
#    '재밌던',
#    '시절',
#    '이었어요',
#    '시골',
#    '에서',
#    '보내셨으면',
#    '야자',
#    '끝나고',
#    '귀가',
#    '할',
#    '때',
#    '별도',
#    '보이셨나요?!',
#    '저는',
#    '공기',
#    '가',
#    '탁한',
#    '곳에서',
#    '지내서',
#    '밤하늘',
#    '에',
#    '별이',
#    '쏟아지는',
#    '걸',
#    '본',
#    '경험',
#    '이',
#    '손에',
#    '꼽는데',
#    '어쩌다가',
#    '한',
#    '번',
#    '밤늦게',
#    '공부',
#    '끝나고',
#    '문득',
#    '하늘',
#    '을',
#    '쳐다봤는데',
#    '그날',
#    '따라',
#    '별이',
#    '총총',
#    '보여서',
#    '홀린',
#    '듯이',
#    '별구경을',
#    '하다가',
#    '간',
#    '기억',
#    '이',
#    '있어요'],
#   ['엄청',
#    '잘',
#    '보이는',
#    '건',
#    '아니었지만',
#    '그래도',
#    '꽤',
#    '본',
#    '것',
#    '같아요!',
#    '야자',
#    '끝나면',
#    '밤이니까',
#    '별',
#    '보며',
#    '하교',
#    '하거나',
#    '개구리',
#    '소리',
#    '를',
#    'bgm',
#    '삼아서요',
#    '동아리',
#    '활동',
#    '은',
#    '하셨나요?',
#    '저희',
#    '는',
#    '동아리',
#    '랄',
#    '것도',
#    '거의',
#    '없어서ᅲᅲ',
#    '드라마',
#    '나',
#    '영화',
#    '만화',
#    '에서',
#    '하는',
#    '동아리',
#    '활동',
#    '이나',
#    '학교',
#    '축제',
#    '를',
#    '동경',
#    '했어요'],
#   ['개구리',
#    'bgm',
#    '과',
#    '별구경ᄏᄏᄏᄏ낭만적이에요',
#    '저희',
#    '학교',
#    '도',
#    '동아리',
#    '가',
#    '화려',
#    '한',
#    '편은',
#    '아니었어',
#    '요',
#    '축제',
#    '를',
#    '하긴',
#    '했는데',
#    '막',
#    '정말',
#    '페스티벌',
#    '느낌',
#    '은',
#    '아니었고',
#    '뭐라지',
#    '각',
#    '부서별로',
#    '우리',
#    '는',
#    '이런',
#    '활동',
#    '을',
#    '해요',
#    '하고',
#    '맛보기를',
#    '보여주는',
#    '정도',
#    '였어요',
#    '저희',
#    '쪽도',
#    '전형적',
#    '인',
#    '한국',
#    '동아리',
#    '였어요',
#    '옆',
#    '나라',
#    '드라마',
#    '나',
#    '영화',
#    '보면',
#    '동아리',
#    '제도',
#    '가',
#    '정말',
#    '잘',
#    '되어있는데',
#    '저도',
#    '그걸',
#    '되게',
#    '부러워',
#    '했어요',
#    '청춘',
#    '그',
#    '자체',
#    '같아서요',
#    '특히',
#    '밴드',
#    '부',
#    '공연',
#    '하는',
#    '게',
#    '얼마',
#    '나',
#    '멋져',
#    '보이던',
#    '지',
#    '한',
#    '번쯤',
#    '경험',
#    '해보고',
#    '싶은',
#    '생각',
#    '이',
#    '아직',
#    '도',
#    '있어요'],
#   ['아',
#    '맞아요',
#    '!',
#    '저도',
#    '그랬어요',
#    'ㅠㅠ',
#    '학생',
#    '들끼리',
#    '반마다',
#    '여러',
#    '가지',
#    '테마',
#    '로',
#    '카페',
#    '도',
#    '하고',
#    '연극',
#    '도',
#    '하고',
#    '밴드',
#    '가',
#    '최고지요',
#    '대학',
#    '교',
#    '때도',
#    '동아리',
#    '활동',
#    '을',
#    '못해봐서',
#    '좀',
#    '아쉽네요'],
#   ['저도',
#    '요',
#    '뭔가',
#    '학창시절',
#    '에',
#    '못다',
#    '한',
#    '활동',
#    '들이',
#    '아쉬움',
#    '으로',
#    '남아',
#    '요',
#    '그래서',
#    '아쉬운',
#    '대로',
#    '앞으로',
#    '살면서',
#    '취미',
#    '모임',
#    '같은',
#    '게',
#    '있으면',
#    '참여',
#    '해보려고요',
#    '비전문가',
#    '취미',
#    '밴드',
#    '모임',
#    '이라던가',
#    '하고',
#    '싶었던',
#    '일들',
#    '은',
#    '다',
#    '하고',
#    '무덤',
#    '들어가는',
#    '게',
#    '꿈입니다',
#    '개구리',
#    '소리',
#    '들으며',
#    '별도',
#    '보고',
#    '말',
#    '거여요!',
#    '은',
#    '학창시절',
#    '좋아',
#    '하는',
#    '먹거리',
#    '가',
#    '있었나요?',
#    '전',
#    '가끔',
#    '먹는',
#    '포장',
#    '마차',
#    '떡꼬',
#    '치가',
#    '너무',
#    '좋았어요'],
#   ['취미',
#    '밴드',
#    '모임',
#    '아주',
#    '좋은',
#    '것',
#    '같아요!',
#    '멋있어요',
#    '앗',
#    '저도',
#    '요ㅠㅠ',
#    '떡꼬',
#    '치',
#    '너무',
#    '맛있었어요ㅠㅠ',
#    '더',
#    '어릴',
#    '때로',
#    '돌아',
#    '가면',
#    '피카츄',
#    '모양',
#    '꼬지',
#    '정말',
#    '초등학생',
#    '때는',
#    '그것',
#    '만',
#    '손에',
#    '쥐면',
#    '행복',
#    '했어요',
#    '그리고',
#    '요새',
#    '파는',
#    '두꺼운',
#    '와플',
#    '말고',
#    '얇은',
#    '와플',
#    '에',
#    '생크림',
#    '딸기잼',
#    '이오!',
#    '야자',
#    '하다가',
#    '배달',
#    '시켜',
#    '먹었는데',
#    '꿀맛',
#    '이었어요',
#    '잊지',
#    '못할',
#    '맛이에요'],
#   ['피카츄',
#    '와',
#    '학창시절',
#    '대표',
#    '군것질',
#    '아닌가요!',
#    '저도',
#    '진짜',
#    '좋아',
#    '했어요',
#    '맨날',
#    '귀랑',
#    '다리',
#    '부터',
#    '먹어서',
#    '눈사람',
#    '모양',
#    '만들곤',
#    '했어요',
#    '저도',
#    '얇은',
#    '와플',
#    '진짜',
#    '좋아해요!',
#    '요즘',
#    '카페',
#    '에서',
#    '파는',
#    '고상한(?)',
#    '와플',
#    '말고',
#    '시장',
#    '표',
#    '와플',
#    '이라',
#    '해야',
#    '하나',
#    '생크림',
#    '에',
#    '딸기잼',
#    '이나',
#    '사과잼',
#    '아니면',
#    '초코시럽',
#    '뿌리기만',
#    '한',
#    '건데도',
#    '너무',
#    '맛있었던',
#    '떠올리니',
#    '또',
#    '먹고',
#    '싶네요',
#    '침',
#    '나온다!',
#    '문방구',
#    '불량식품',
#    '도',
#    '종종',
#    '먹었는데',
#    '은',
#    '불량식품',
#    '드셨나요?']],
#  [['아뇨!',
#    '저는',
#    '딱히',
#    '큰',
#    '계획',
#    '은',
#    '세우지',
#    '않아요',
#    '그냥',
#    '1년',
#    '에',
#    '12권',
#    '이면',
#    '감사',
#    '하다',
#    '정도',
#    '!?!',
#    '은요??',
#    '전',
#    '그래서',
#    '밀리의',
#    '서재',
#    '를',
#    '구독',
#    '했답니다',
#    '그래도',
#    '안',
#    '보는',
#    '건',
#    '매한가지기는해요ㅜㅜ'],
#   ['전',
#    '재작년',
#    '에',
#    '12권',
#    '작년',
#    '에',
#    '24',
#    '권',
#    '읽기',
#    '도전',
#    '했는데',
#    '연말',
#    '에',
#    '겨우겨우',
#    '채웠어요',
#    '올해',
#    '는',
#    '무계획',
#    '으로',
#    '살고',
#    '있는데',
#    '계획',
#    '이',
#    '없다',
#    '보니까',
#    '책이랑',
#    '더',
#    '멀어지는',
#    '것',
#    '같아요',
#    '오',
#    '그래도',
#    '실천',
#    '하면',
#    '그게',
#    '반이잖아요~',
#    '근데',
#    '저도',
#    '밀리의',
#    '서재',
#    '구독',
#    '해봤는데',
#    '자꾸',
#    '보다',
#    '말다',
#    '하더라고요',
#    'ㅠ',
#    '의지박약',
#    '이죠',
#    'ㅠㅠ'],
#   ['와',
#    '대단',
#    '하세요!!!!',
#    '24',
#    '권',
#    '우와',
#    '대단',
#    '하신데요?!?!?!',
#    '아놔',
#    '저도',
#    '그래요!',
#    '밀리의',
#    '서재',
#    '완독',
#    '한',
#    '건',
#    '2권',
#    '밖에',
#    '안되고요ㅠㅠ',
#    '읽고',
#    '싶은',
#    '책을',
#    '돌려보기',
#    '중입니다',
#    '그러다',
#    '보면',
#    '3권',
#    '은',
#    '읽겠지라고',
#    '생각',
#    '중이네요'],
#   ['힘들더라고요',
#    '생각',
#    '보다',
#    'ㅠㅠㅠ',
#    '한',
#    '달에',
#    '두',
#    '권',
#    '읽으면',
#    '되겠지라고',
#    '생각',
#    '했는데',
#    '그게',
#    '잘',
#    '안돼요',
#    '오',
#    '그래도',
#    '구독',
#    '하고',
#    '꾸준',
#    '하게',
#    '읽고',
#    '계신',
#    '거잖아요!',
#    '원래',
#    '꾸준',
#    '하게',
#    '하는',
#    '게',
#    '좋아',
#    '요!',
#    '꾸준',
#    '함을',
#    '이길',
#    '수',
#    '있는',
#    '건',
#    '없어요~',
#    '저도',
#    '한동안',
#    '게을렀는데',
#    '이번',
#    '주부',
#    '터',
#    '다시',
#    '뭐라도',
#    '읽어야겠어요'],
#   ['맞아요',
#    'ㅠㅠㅠ',
#    '한',
#    '달에',
#    '두',
#    '권',
#    '읽는다는',
#    '게',
#    '제일',
#    '어렵더라고요',
#    '쓰자',
#    '읍',
#    'ㅠㅠ',
#    '그래도',
#    '하루',
#    '에',
#    '한',
#    '줄',
#    '읽기는',
#    '해보고',
#    '있어요',
#    '맞아요',
#    '맞아요',
#    '꾸준',
#    '함이',
#    '중요',
#    '하죠!!!!',
#    '그래도',
#    '책',
#    '엄청',
#    '많이',
#    '읽으신',
#    '거',
#    '같은데',
#    '요!?!?!?!?'],
#   ['우와',
#    '정말',
#    '꾸준',
#    '하게',
#    '잘하시네요',
#    '본받아야겠어요!',
#    '하루',
#    '에',
#    '한',
#    '줄',
#    '읽기는',
#    '딱',
#    '한',
#    '줄만',
#    '읽는',
#    '건가요?',
#    '그것',
#    '도',
#    '나쁘지',
#    '않을',
#    '것',
#    '같아요',
#    '진짜',
#    '한',
#    '줄도',
#    '잘',
#    '안',
#    '읽는',
#    '날이',
#    '대부분',
#    '이라',
#    'ㅠㅠ',
#    '아니에요',
#    '과거형',
#    '이에요',
#    'ㅠㅠ',
#    '어느',
#    '순간',
#    '부터',
#    '게으름뱅이',
#    '가',
#    '되었어요'],
#   ['네!',
#    '한',
#    '줄만',
#    '일단',
#    '읽고',
#    '재밌으면',
#    '더',
#    '줄줄',
#    '읽고',
#    '그러거든요!',
#    '어느',
#    '날은',
#    '몇십',
#    '장',
#    '읽고',
#    '어느',
#    '날은',
#    '딱',
#    '한',
#    '줄',
#    '읽고',
#    '덮고',
#    '이게',
#    '부담감',
#    '이',
#    '덜하더라고요!!!',
#    '에이',
#    '저도',
#    '마찬가지',
#    '인데요',
#    '뭘!'],
#   ['제가',
#    '의무적',
#    '으로',
#    '읽으려고',
#    '해서',
#    '더',
#    '안',
#    '읽혔나',
#    '봐요',
#    '아무래',
#    '도',
#    '책',
#    '읽기',
#    '한번',
#    '시작',
#    '하면',
#    '어느',
#    '정도',
#    '읽어야',
#    '할',
#    '것',
#    '같은',
#    '마음',
#    '도',
#    '들고',
#    '해서',
#    '꺼려졌는데',
#    '저도',
#    '오늘',
#    '부터',
#    '해봐야겠어요',
#    '에이',
#    '아니에요',
#    '지금',
#    '잘하고',
#    '계셔요',
#    '~'],
#   ['같이',
#    '독서',
#    '왕이',
#    '되어보자고요',
#    '!!!!!!!',
#    '사실',
#    '그',
#    '취향',
#    '에',
#    '맞는',
#    '책',
#    '찾기',
#    '좀',
#    '어렵지',
#    '않나요?!'],
#   ['좋아',
#    '요',
#    '올해',
#    '가',
#    '그리',
#    '많이',
#    '남은',
#    '건',
#    '아니지만',
#    '독서',
#    '왕이',
#    '되어',
#    '보아요~',
#    '맞아요',
#    '!',
#    '그게',
#    '진짜',
#    '어려운',
#    '것',
#    '같아요',
#    'ㅠㅠ그래도',
#    '웬만',
#    '큼',
#    '입소문',
#    '난',
#    '책들',
#    '은',
#    '그래도',
#    '크게',
#    '실패',
#    '하진',
#    '않는',
#    '것',
#    '같아요~'],
#   ['맞아요',
#    'ㅠㅠ!',
#    '저도',
#    '사실',
#    '독서',
#    '기준',
#    '이',
#    '좀',
#    '까다',
#    '로워서',
#    '안',
#    '맞으면',
#    '읽다가',
#    '놓아버리거든요ㅠㅠ',
#    '근데',
#    '입소문',
#    '난',
#    '책들',
#    '은',
#    '거의',
#    '성공',
#    '하는',
#    '편이에요!',
#    '그리고',
#    '자기',
#    '개발',
#    '책만',
#    '아니면',
#    '진짜',
#    '오케이',
#    '입니다'],
#   ['맞아욬',
#    '자기',
#    '개발',
#    '책은',
#    '한트',
#    '럭을',
#    '가져다줘도',
#    '싫어',
#    '요ㅠㅠㅠ',
#    '저도',
#    '그래서',
#    '책',
#    '구매',
#    '하거나',
#    '대여',
#    '할',
#    '때는',
#    '베스트셀러',
#    '위주',
#    '로',
#    '구매',
#    '하거나',
#    '대여',
#    '하는',
#    '편이에요'],
#   ['맞아요',
#    '!',
#    '진짜',
#    '자기',
#    '개발',
#    '책은',
#    '정말',
#    '안',
#    '읽게',
#    '되고',
#    '읽어도',
#    '도움',
#    '안되고ㅠㅠ',
#    '아하',
#    '!',
#    '저는',
#    '일단',
#    '사고',
#    '기부',
#    '합니다',
#    '어차피',
#    '책에',
#    '뭐',
#    '묻거나',
#    '선긋는',
#    '거',
#    '싫어',
#    '해서',
#    '엄청',
#    '깔끔',
#    '하게',
#    '보는',
#    '편이거든요!!!',
#    '기억',
#    '하고',
#    '싶은',
#    '부분',
#    '은',
#    '필사',
#    '해서',
#    '두는',
#    '편입',
#    '니다',
#    '필사',
#    '도',
#    '하시나요?!'],
#   ['오',
#    '멋지신',
#    '게요!',
#    '아뇨',
#    '필사',
#    '하면',
#    '좋다고들',
#    '하는데',
#    '마음',
#    '따로',
#    '몸',
#    '따로라',
#    '필사',
#    '는',
#    '안',
#    '해봤어요~',
#    '필사',
#    '하는',
#    '습관',
#    '정말',
#    '좋은데요?',
#    '보다',
#    '보면',
#    '책',
#    '내용',
#    '도',
#    '기억',
#    '나고']],
#  [['헐',
#    '그것',
#    '도',
#    '만만',
#    '치',
#    '않게',
#    '슬플',
#    '것',
#    '같아요',
#    'ㅠㅠㅠ',
#    '그냥',
#    '소설',
#    '도',
#    '물론',
#    '슬픈',
#    '건',
#    '슬픈데',
#    '역사',
#    '기반',
#    '으로',
#    '한',
#    '소설',
#    '은',
#    '진짜',
#    '너무',
#    '슬퍼요',
#    'ㅠㅠ',
#    '추천',
#    '해주신',
#    '도서',
#    '잘',
#    '적어두고',
#    '다음',
#    '에',
#    '꼭',
#    '볼게',
#    '요',
#    '다',
#    '너무',
#    '좋은',
#    '작품들',
#    '일',
#    '것',
#    '같아요'],
#   ['맞아요',
#    'ㅠㅠ',
#    '진짜',
#    '역사',
#    '기반',
#    '소설',
#    '이',
#    '너무',
#    '슬프죠ㅠㅠ',
#    '그게',
#    '실제',
#    '로',
#    '일어',
#    '났던',
#    '일이라는',
#    '게',
#    '너무',
#    '안타깝고',
#    '마음',
#    '이',
#    '아프더라고요ㅠㅠ',
#    '또',
#    '재미',
#    '있게',
#    '읽으신',
#    '책',
#    '있나요?!?!?!'],
#   ['맞아요',
#    'ㅠㅠ',
#    '그런',
#    '게',
#    '진짜',
#    '마음',
#    '을',
#    '울리더라고요',
#    'ㅠㅠ',
#    '방금',
#    '제가',
#    '뭘',
#    '읽었나',
#    '찾아봤는데',
#    '기억',
#    '나는',
#    '게',
#    '많이',
#    '없네요',
#    'ㅠㅠㅠ',
#    '그중',
#    '에',
#    '무지',
#    '개',
#    '곶의',
#    '찻집',
#    '이라는',
#    '책은',
#    '잔잔',
#    '하니',
#    '재밌게',
#    '읽었었던',
#    '것',
#    '같아요',
#    '그리고',
#    '유명',
#    '한',
#    '나미야',
#    '잡화점',
#    '의',
#    '기적',
#    '도',
#    '잘',
#    '읽었어요!'],
#   ['아',
#    '헐',
#    '나미야',
#    '잡화점',
#    '의',
#    '기적',
#    '재밌죠!!!!!!!!',
#    '무지',
#    '개',
#    '곳의',
#    '찻집',
#    '은',
#    '꼭',
#    '읽어볼게요!',
#    '혹시',
#    '그럼',
#    '그',
#    '책',
#    '읽어보셨나요?',
#    '돌이',
#    '킬',
#    '수',
#    '없는<이라는',
#    '책도',
#    '재밌어요!',
#    '술술',
#    '읽히더라고요!'],
#   ['그냥',
#    '가볍게',
#    '보기',
#    '좋은',
#    '책일',
#    '거예요~',
#    '아뇨',
#    '돌이',
#    '킬',
#    '수',
#    '없는',
#    '약속',
#    '이란',
#    '책인가요??'],
#   ['아니요', '!', '돌이', '킬', '수', '있는', '있는', '이에요', '헷갈렸어요', '죄송', '합니다ㅜㅜ!!!'],
#   ['아니에요',
#    '이름',
#    '이',
#    '비슷',
#    '해서',
#    '저도',
#    '처음',
#    '에는',
#    '있는으로',
#    '쳤는데',
#    '없는',
#    '이란',
#    '책도',
#    '있더라고요',
#    '근데',
#    '너무',
#    '웹',
#    '소설',
#    '느낌',
#    '이라',
#    '여쭤본',
#    '거였어요~',
#    '오',
#    '설명',
#    '을',
#    '보니까',
#    '엄청',
#    '재밌어',
#    '보여요~',
#    '지금',
#    '봐야',
#    '할',
#    '책들',
#    '이',
#    '늘어',
#    '서',
#    '너무',
#    '즐겁네요',
#    '은',
#    '정말',
#    '책을',
#    '좋아',
#    '하시나',
#    '봐요',
#    '~'],
#   ['아니에요!',
#    '좋아',
#    '하는',
#    '건',
#    '아니고',
#    '성인',
#    '이',
#    '되어서',
#    '책을',
#    '안',
#    '읽었더니',
#    '어휘력',
#    '에',
#    '문제',
#    '가',
#    '생기는',
#    '거예요',
#    '뭐만',
#    '해도',
#    '자꾸',
#    '대박',
#    '최고다~',
#    '이러고',
#    '있더라고요ㅠㅠ',
#    '그래서',
#    '늘리려고',
#    '책을',
#    '읽었는데쓰읍똑같네요아놔',
#    '그냥',
#    '즐기는',
#    '사람',
#    '이',
#    '되어버렸답니다',
#    '언젠',
#    '간',
#    '늘겠지',
#    '하고',
#    '있어요',
#    '!!'],
#   ['에이',
#    '그래도',
#    '엄청',
#    '드라마',
#    '틱',
#    '하게',
#    '와닿진',
#    '않아도',
#    '어휘력',
#    '이',
#    '많이',
#    '느셨을',
#    '거예요',
#    '저는',
#    '요즘',
#    '읽은',
#    '책이라곤',
#    '주식',
#    '책이',
#    '여가',
#    '지구',
#    '갈수록',
#    '퇴화되고',
#    '있어요',
#    'ㅠㅠ',
#    '안',
#    '그래도',
#    '어휘력',
#    '이',
#    '바닥',
#    '인데',
#    '책은',
#    '한번',
#    '시작',
#    '하면',
#    '쭉',
#    '읽는데',
#    '읽기까지',
#    '맘먹기가',
#    '힘들어',
#    '요',
#    'ㅠㅠ'],
#   ['아하',
#    '!',
#    '주식',
#    '책도',
#    '도움',
#    '이',
#    '많이',
#    '될',
#    '거예요!',
#    '어떤',
#    '책이든',
#    '읽으면',
#    '도움',
#    '이',
#    '된다',
#    '그랬어요',
#    '!',
#    '저도',
#    '마찬가지',
#    '라서',
#    '하루',
#    '에',
#    '한',
#    '시간',
#    '은',
#    '투자',
#    '하려고',
#    '하고',
#    '있답니다',
#    '쉽지가',
#    '않지만요!!'],
#   ['오',
#    '그렇담',
#    '너무',
#    '좋을',
#    '것',
#    '같아요',
#    '와',
#    '하루',
#    '한',
#    '시간',
#    '은',
#    '대단',
#    '하신데요!저는',
#    '출퇴근',
#    '에',
#    '보려',
#    '했는데',
#    '집중',
#    '이',
#    '영',
#    '안되더라고요'],
#   ['와!',
#    '출퇴근',
#    '시간',
#    '에',
#    '보시는',
#    '게',
#    '더',
#    '대단',
#    '하신걸요!!!',
#    '저는',
#    '취진',
#    '생이라',
#    '자기',
#    '전에',
#    '읽으려고',
#    '하거든요ㅜㅜ']],
#  [['이',
#    '주제',
#    '가',
#    '이것',
#    '도',
#    '될는지',
#    '모르겠는데ㅔ',
#    '네',
#    '혹시',
#    '카페',
#    '투어',
#    '도',
#    '좋아',
#    '하시나요?!'],
#   ['네!',
#    '저',
#    '카페',
#    '투어',
#    '도',
#    '너무',
#    '좋아',
#    '합니다',
#    '여행',
#    '가면',
#    '꼭',
#    '카페',
#    '여러',
#    '곳',
#    '들렸다',
#    '오곤',
#    '해요!',
#    '님은요?'],
#   ['저는',
#    '최근',
#    '에',
#    '카페',
#    '부시는',
#    '맛을',
#    '깨달아서ㅓ',
#    '얼마',
#    '전에',
#    '경주',
#    '갔을',
#    '때',
#    '맘에',
#    '드는',
#    '카페',
#    '하나',
#    '찾고',
#    '왔어요!',
#    '저는',
#    '주로',
#    '넓고',
#    '뷰가',
#    '좋은',
#    '카페',
#    '를',
#    '좋아',
#    '하는데',
#    '님은',
#    '어떤',
#    '카페',
#    '가',
#    '취향이신가요??'],
#   ['와',
#    '좋으셨겠다!',
#    '저도',
#    '넓고',
#    '뷰가',
#    '좋은',
#    '카페',
#    '너무',
#    '좋아',
#    '하는데',
#    '분위기가',
#    '좋은',
#    '카페',
#    '를',
#    '더',
#    '선호',
#    '하는',
#    '것',
#    '같아요!',
#    '조명',
#    '이',
#    '잔잔',
#    '한',
#    '곳이오!',
#    '저번',
#    '에',
#    '부산',
#    '여행',
#    '을',
#    '갔는데',
#    '거기에',
#    '그런',
#    '카페',
#    '가',
#    '있어서',
#    '엄청',
#    '놀랐었어요',
#    '!'],
#   ['헐헐',
#    '완전',
#    '기분',
#    '좋으셨겠어요',
#    '!!!',
#    '그리고',
#    '부산',
#    '여행',
#    '이라니!!!',
#    '전',
#    '부산',
#    '은',
#    '한',
#    '번도',
#    '안',
#    '가봐서',
#    '제',
#    '위시리스트',
#    '에',
#    '있는',
#    '곳',
#    '중',
#    '하나',
#    '거든요',
#    '광안대교',
#    '?',
#    '가',
#    '그르케',
#    '예쁘다던데',
#    '사실',
#    '인가요',
#    '네임'],
#   ['아',
#    '쓸',
#    '진짜',
#    '아쉽게도',
#    '비가',
#    '많이',
#    '와서',
#    '바닷가',
#    '금지',
#    '였어요',
#    '저도',
#    '진짜',
#    '거짓말',
#    '해서라도',
#    '알려드리고',
#    '싶었는데',
#    '하',
#    '진짜',
#    '아쉽네요',
#    '님',
#    '여행',
#    '가보신',
#    '곳',
#    '자랑',
#    '해주세요',
#    '저',
#    '여행',
#    '을',
#    '많은',
#    '곳을',
#    '못',
#    '다녔고든',
#    '요!'],
#   ['ㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠ',
#    '이런',
#    '텍스트',
#    '만',
#    '봐도',
#    '맴',
#    '아픈',
#    '게',
#    '전해지네요ㅠㅠㅠㅠㅠㅠ',
#    '사실',
#    '제가',
#    '파워',
#    '집',
#    '순이',
#    '라',
#    '자랑',
#    '이라기엔',
#    '조금',
#    '부끄럽지만',
#    '올해',
#    '국내여행',
#    '은',
#    '경주',
#    '랑',
#    '평창',
#    '동해',
#    '쪽',
#    '이렇게',
#    '다녀왔었어요!!',
#    '그리고',
#    '저는',
#    '가족여행',
#    '을',
#    '주로',
#    '많이',
#    '가는데',
#    '여행',
#    '목적',
#    '이',
#    '식도락',
#    '이라',
#    '맛집',
#    '부시는',
#    '데에',
#    '진심',
#    '이에요'],
#   ['와',
#    '헐',
#    '저도',
#    '요',
#    '원래',
#    '여행',
#    '=맛',
#    '집',
#    '털고',
#    '다니기',
#    '아닌가요?!',
#    '경주',
#    '저도',
#    '너무',
#    '가고싶어요ㅠㅠㅠ',
#    '경주',
#    '맛있는',
#    '곳',
#    '있나요?!?!?!?!?'],
#   ['진리',
#    '의',
#    '사바',
#    '사는',
#    '언제',
#    '나',
#    '고려',
#    '하셔야겠지만',
#    '저는',
#    '경주',
#    '맛',
#    '집이라고',
#    '하면',
#    '함량',
#    '집이랑',
#    '용산',
#    '회식',
#    '당',
#    '이렇게',
#    '추천',
#    '드리고',
#    '싶어요!!!',
#    '물론',
#    '황리',
#    '딴',
#    '길이',
#    '라고',
#    '핫한',
#    '길',
#    '가면',
#    '파스타',
#    '맛',
#    '집들',
#    '도',
#    '있다고',
#    '하는데',
#    '황리',
#    '딴',
#    '길은',
#    '주차',
#    '가',
#    '힘들어',
#    '서',
#    '잘',
#    '안',
#    '가게',
#    '되더라고요ᅲ',
#    '함양',
#    '짚은',
#    '한우',
#    '물회',
#    '가',
#    '존',
#    '만이고',
#    '요산회',
#    '식당',
#    '은',
#    '회덮밥',
#    '하는',
#    '집인',
#    '데',
#    '회덮밥',
#    '이',
#    '뭐',
#    '그리',
#    '대단',
#    '하냐',
#    '하실',
#    '수',
#    '있지만',
#    '진짜',
#    '짱짱',
#    '맛집이에요최고됩니다',
#    '정말로'],
#   ['와',
#    '와',
#    '한우',
#    '물회',
#    '요?',
#    '저',
#    '진짜',
#    '한',
#    '번도',
#    '안',
#    '먹어봤는데',
#    '지금',
#    '너무',
#    '먹어보고',
#    '싶어요',
#    '한우',
#    '물회',
#    '와',
#    '얼마',
#    '나',
#    '맛있을까요?ㅠㅠ'],
#   ['한우',
#    '물회',
#    '제가',
#    '2박',
#    '3일',
#    '동안',
#    '1일',
#    '1물회',
#    '부실',
#    '정도',
#    '로',
#    '짱맛',
#    '이에요ㅠㅠㅠㅠㅠ',
#    '네임',
#    '께도',
#    '하루',
#    '빨리',
#    '경주',
#    '여행',
#    '의',
#    '기회',
#    '가',
#    '왔으면',
#    '좋겠네요!!'],
#   ['하',
#    '진짜',
#    '1일',
#    '1물회',
#    '정도',
#    '면',
#    '찐인거잖아요ㅠㅠㅠㅠ',
#    '저',
#    '지금',
#    '너무',
#    '경주',
#    '가',
#    '가고',
#    '싶어졌어요',
#    '동해',
#    '도',
#    '진짜',
#    '즐거우셨겠어요',
#    '식도락',
#    '여행',
#    '이었으면',
#    '그렇죠'],
#   ['동해', '는', '해산물', '부시러', '다녀왔습니다ㅏ', '대게', '먹었었는데ㅔ', 'ㅏ', '또', '가고', '싶네요'],
#   ['대게',
#    '요?',
#    '진짜',
#    '님',
#    '반칙',
#    '이잖아요',
#    '이',
#    '시간',
#    '에',
#    '대게',
#    '얘기',
#    '?',
#    '반칙',
#    'ㅠㅠㅠ',
#    '하',
#    '저도',
#    '너무',
#    '먹고싶어요ㅠㅠㅠㅠㅠ',
#    '저는',
#    '부신',
#    '가서',
#    '랍스터',
#    '먹었는데',
#    '생각',
#    '보다',
#    '맛이',
#    '별로여서',
#    '놀랐거든요ㅜㅜ']],
#  [['안녕',
#    '하세요',
#    '반갑습니다^^',
#    '요즘',
#    '비가',
#    '자주',
#    '오던데',
#    '지역',
#    '에',
#    '비',
#    '피해',
#    '는',
#    '없나요?'],
#   ['안녕', '하세요', '다행히', '비', '피해', '는', '없어요', '오늘', '도', '비가', '오네', '요!'],
#   ['여기도', '하루', '종일', '비가', '오고', '있습니다', '비', '좋아하세요?'],
#   ['음',
#    '집에만',
#    '있는',
#    '날에',
#    '적당히',
#    '오는',
#    '비는',
#    '좋아',
#    '해요',
#    '분위기',
#    '있고~',
#    '외출',
#    '해야',
#    '하는데',
#    '비',
#    '오면',
#    '힘들고요',
#    '후'],
#   ['맞아요',
#    '집에서',
#    '듣는',
#    '빗소리',
#    '는',
#    '좋은데',
#    '돌아',
#    '다닐',
#    '땐',
#    '축축',
#    '하죠',
#    '님은',
#    '어느',
#    '계절',
#    '은',
#    '가장',
#    '좋아하나요?'],
#   ['저는',
#    '음',
#    '봄이',
#    '나',
#    '가을',
#    '이',
#    '가장',
#    '좋아',
#    '요!',
#    '초여름',
#    '이나',
#    '초가을',
#    '도',
#    '좋아',
#    '요',
#    '님은',
#    '어느',
#    '계절',
#    '을',
#    '가장',
#    '좋아하세요?'],
#   ['가을',
#    '을',
#    '가장',
#    '좋아',
#    '해요',
#    '지금',
#    '장마',
#    '라',
#    '가을',
#    '느낌',
#    '안',
#    '나지만',
#    '장마',
#    '끝나면',
#    '제가',
#    '좋아',
#    '하는',
#    '느낌',
#    '이',
#    '나겠지요'],
#   ['오', '맞아요', '가을', '이', '오고', '있어요!', '가을', '을', '왜', '가장', '좋아하세요?'],
#   ['일단',
#    '단풍',
#    '을',
#    '좋아',
#    '해요',
#    '하하',
#    '그리고',
#    '높고',
#    '파란',
#    '하늘',
#    '과',
#    '선선',
#    '한',
#    '공기',
#    '를',
#    '좋아',
#    '하죠'],
#   ['맞아요',
#    '단풍',
#    '너무',
#    '예쁘죠',
#    '파란',
#    '하늘',
#    '도',
#    '정말',
#    '좋아',
#    '요',
#    '다만',
#    '해가',
#    '빨리',
#    '점점',
#    '빨리',
#    '지는',
#    '게',
#    '조금',
#    '슬퍼요ㅠ'],
#   ['그래요',
#    '이제',
#    '해가',
#    '짧아지고',
#    '있어요',
#    '밤이',
#    '긴',
#    '게',
#    '겨울',
#    '의',
#    '느낌',
#    '이라',
#    '점점',
#    '겨울',
#    '이',
#    '오는',
#    '기분',
#    '이에요'],
#   ['그쳐ㅠ',
#    '겨울',
#    '엔',
#    '해',
#    '뜨기',
#    '전에',
#    '출근',
#    '했다가',
#    '해지',
#    '고',
#    '퇴근',
#    '하는',
#    '게',
#    '너무',
#    '슬퍼요']]]
